# %%
import pickle

# %%
def load_pickle(file_path):
    """
    Load a pickle file and return the object contained within it.

    :param file_path: Path to the pickle file.
    :return: The object loaded from the pickle file.
    """
    try:
        with open(file_path, 'rb') as file:
            return pickle.load(file)
    except Exception as e:
        print(f"Error loading pickle file: {e}")
        return None

# %%
train_set_names = [
    "trained_on_nail_dataset_v5_train_default",
    "trained_on_mvtec_default",
    "trained_on_visa_default",
]
TEST_DATASET_NAME = "test_on_hard_test_case"

# %%
result_dict_nail = load_pickle(f'/workspace/poc_jci_Crane/results/trained_on_nail_dataset_v5_train_default/{TEST_DATASET_NAME}/magnesium-massachusetts/epoch_5/results.pkl')
print("Nail dataset results loaded successfully.")
result_dict_mvtec = load_pickle(f'/workspace/poc_jci_Crane/results/trained_on_mvtec_default/{TEST_DATASET_NAME}/magnesium-massachusetts/epoch_5/results.pkl')
print("MVTec dataset results loaded successfully.")
result_dict_visa = load_pickle(f'/workspace/poc_jci_Crane/results/trained_on_visa_default/{TEST_DATASET_NAME}/magnesium-massachusetts/epoch_5/results.pkl')
print("VISA dataset results loaded successfully.")
# Out:
# Nail dataset results loaded successfully.
# MVTec dataset results loaded successfully.
# VISA dataset results loaded successfully.

# %%
# Get Each sample's path & predtction & ground truth
import pandas as pd

result_df_dict = {}
for train_set_name in ["nail", "mvtec", "visa"]:
    result_dict = eval(f"result_dict_{train_set_name}")
    result_df_dict[train_set_name] = pd.DataFrame(
        {
            "img_paths": result_dict[0]["img_paths"],
            "gt_sp": [gt.item() for gt in result_dict[0]["gt_sp"]],
            "pr_sp": [pr.item() for pr in result_dict[0]["pr_sp"]],
        }
    )

# %%
result_df_dict["nail"].head()
# Out:
#                                            img_paths  gt_sp     pr_sp
# 0  /workspace/data/hard_test_case/test/nail/fault...      1  0.442821
# 1  /workspace/data/hard_test_case/test/nail/fault...      1  0.395860
# 2  /workspace/data/hard_test_case/test/nail/fault...      1  0.331715
# 3  /workspace/data/hard_test_case/test/nail/fault...      1  0.551333
# 4  /workspace/data/hard_test_case/test/nail/fault...      1  0.331385

# %%
from sklearn.metrics import precision_recall_curve, f1_score, accuracy_score, precision_score, recall_score

def find_best_threshold(gt, scores, method="max_f1"):
    """
    Args:
        gt: Ground truth labels (list or np.array), shape (N,)
        scores: Model anomaly scores (list or np.array), shape (N,)
        method: "max_f1" | "youden_j"

    Returns:
        best_threshold: 최적 threshold
        best_metrics: dict (precision, recall, f1, accuracy)
    """
    precision, recall, thresholds = precision_recall_curve(gt, scores)
    f1_scores = 2 * precision * recall / (precision + recall + 1e-8)

    if method == "max_f1":
        best_idx = f1_scores.argmax()
        best_threshold = thresholds[best_idx]
    elif method == "youden_j":
        # Youden's J: TPR - FPR 를 최대화하는 threshold
        from sklearn.metrics import roc_curve
        fpr, tpr, roc_thresholds = roc_curve(gt, scores)
        j_scores = tpr - fpr
        best_idx = j_scores.argmax()
        best_threshold = roc_thresholds[best_idx]
    else:
        raise ValueError("Unknown method")

    # 이진 분류로 변환
    pred_binary = (scores >= best_threshold).astype(int)

    best_metrics = {
        "threshold": best_threshold,
        "precision": precision_score(gt, pred_binary),
        "recall": recall_score(gt, pred_binary),
        "f1": f1_score(gt, pred_binary),
        "accuracy": accuracy_score(gt, pred_binary),
    }

    return best_threshold, best_metrics

# %%
train_set_names
# Out:
# ['trained_on_nail_dataset_v5_train_default',
#  'trained_on_mvtec_default',
#  'trained_on_visa_default']

# %%
# gt: [0, 1, 0, 1, 0, ...]
# scores: [0.12, 0.95, 0.3, 0.88, 0.15, ...]
for train_set_name, train_set_dir in zip(["nail", "mvtec", "visa"], train_set_names):
    result_df = result_df_dict[train_set_name]
    best_th, metrics = find_best_threshold(result_df["gt_sp"], result_df["pr_sp"], method="youden_j")

    print("Best Threshold:", best_th)
    print("Metrics at best threshold:")
    for k, v in metrics.items():
        print(f"{k}: {v:.4f}")
    result_df["pr_sp_binary"] = (result_df["pr_sp"] >= best_th).astype(int)
    result_df["failure"] = result_df["pr_sp_binary"] != result_df["gt_sp"]
    # Save the result DataFrame with binary predictions
    result_df.to_csv(f"/workspace/poc_jci_Crane/results/{train_set_dir}/{TEST_DATASET_NAME}/magnesium-massachusetts/epoch_5/results_with_binary_best_threshold_{best_th}_youden_j.csv", index=False)
# Out:
# Best Threshold: 0.3128008544445038
# Metrics at best threshold:
# threshold: 0.3128
# precision: 0.7288
# recall: 0.8600
# f1: 0.7890
# accuracy: 0.7677
# Best Threshold: 0.4002387225627899
# Metrics at best threshold:
# threshold: 0.4002
# precision: 0.8000
# recall: 0.8800
# f1: 0.8381
# accuracy: 0.8283
# Best Threshold: 0.335653692483902
# Metrics at best threshold:
# threshold: 0.3357
# precision: 0.8070
# recall: 0.9200
# f1: 0.8598
# accuracy: 0.8485

# %%
# gt: [0, 1, 0, 1, 0, ...]
# scores: [0.12, 0.95, 0.3, 0.88, 0.15, ...]
for train_set_name, train_set_dir in zip(["nail", "mvtec", "visa"], train_set_names):
    result_df = result_df_dict[train_set_name]
    best_th, metrics = find_best_threshold(result_df["gt_sp"], result_df["pr_sp"], method="max_f1")

    print("Best Threshold:", best_th)
    print("Metrics at best threshold:")
    for k, v in metrics.items():
        print(f"{k}: {v:.4f}")
    result_df["pr_sp_binary"] = (result_df["pr_sp"] >= best_th).astype(int)
    result_df["failure"] = result_df["pr_sp_binary"] != result_df["gt_sp"]
    # Save the result DataFrame with binary predictions
    result_df.to_csv(f"/workspace/poc_jci_Crane/results/{train_set_dir}/{TEST_DATASET_NAME}/magnesium-massachusetts/epoch_5/results_with_binary_best_threshold_{best_th}.csv", index=False)
# Out:
# Best Threshold: 0.30018168687820435
# Metrics at best threshold:
# threshold: 0.3002
# precision: 0.6970
# recall: 0.9200
# f1: 0.7931
# accuracy: 0.7576
# Best Threshold: 0.4002387225627899
# Metrics at best threshold:
# threshold: 0.4002
# precision: 0.8000
# recall: 0.8800
# f1: 0.8381
# accuracy: 0.8283
# Best Threshold: 0.335653692483902
# Metrics at best threshold:
# threshold: 0.3357
# precision: 0.8070
# recall: 0.9200
# f1: 0.8598
# accuracy: 0.8485

# %%
result_df_dict["nail"][result_df_dict["nail"]["failure"]]
# Out:
#                                             img_paths  gt_sp     pr_sp  \
# 14  /workspace/data/hard_test_case/test/nail/fault...      1  0.281871
# 23  /workspace/data/hard_test_case/test/nail/fault...      1  0.235527
# 24  /workspace/data/hard_test_case/test/nail/fault...      1  0.255743
# 28  /workspace/data/hard_test_case/test/nail/fault...      1  0.250162
# 50  /workspace/data/hard_test_case/test/nail/good/...      0  0.581607
# 52  /workspace/data/hard_test_case/test/nail/good/...      0  0.311107
# 55  /workspace/data/hard_test_case/test/nail/good/...      0  0.496947
# 56  /workspace/data/hard_test_case/test/nail/good/...      0  0.470409
# 57  /workspace/data/hard_test_case/test/nail/good/...      0  0.497625
# 58  /workspace/data/hard_test_case/test/nail/good/...      0  0.335207
# 60  /workspace/data/hard_test_case/test/nail/good/...      0  0.396102
# 63  /workspace/data/hard_test_case/test/nail/good/...      0  0.307574
# 64  /workspace/data/hard_test_case/test/nail/good/...      0  0.354415
# 70  /workspace/data/hard_test_case/test/nail/good/...      0  0.420742
# 72  /workspace/data/hard_test_case/test/nail/good/...      0  0.369839
# 80  /workspace/data/hard_test_case/test/nail/good/...      0  0.346166
# 81  /workspace/data/hard_test_case/test/nail/good/...      0  0.333719
# 84  /workspace/data/hard_test_case/test/nail/good/...      0  0.351885
# 85  /workspace/data/hard_test_case/test/nail/good/...      0  0.390968
# 86  /workspace/data/hard_test_case/test/nail/good/...      0  0.309208
# 91  /workspace/data/hard_test_case/test/nail/good/...      0  0.371373
# 92  /workspace/data/hard_test_case/test/nail/good/...      0  0.307591
# 97  /workspace/data/hard_test_case/test/nail/good/...      0  0.488842
# 98  /workspace/data/hard_test_case/test/nail/good/...      0  0.560441
#
#     pr_sp_binary  failure
# 14             0     True
# 23             0     True
# 24             0     True
# 28             0     True
# 50             1     True
# 52             1     True
# 55             1     True
# 56             1     True
# 57             1     True
# 58             1     True
# 60             1     True
# 63             1     True
# 64             1     True
# 70             1     True
# 72             1     True
# 80             1     True
# 81             1     True
# 84             1     True
# 85             1     True
# 86             1     True
# 91             1     True
# 92             1     True
# 97             1     True
# 98             1     True

# %%
for train_set_name, train_set_dir in zip(["nail", "mvtec", "visa"], train_set_names):

    result_df_dict[train_set_name][result_df_dict[train_set_name]["failure"]].to_csv(
        f"/workspace/poc_jci_Crane/results/{train_set_dir}/{TEST_DATASET_NAME}/magnesium-massachusetts/epoch_5/failure_samples.csv",
        index=False)

# %%
result_df_dict["mvtec"][result_df_dict["mvtec"]["failure"]]
# Out:
#                                             img_paths  gt_sp     pr_sp  \
# 14  /workspace/data/hard_test_case/test/nail/fault...      1  0.357465
# 17  /workspace/data/hard_test_case/test/nail/fault...      1  0.321199
# 23  /workspace/data/hard_test_case/test/nail/fault...      1  0.217706
# 24  /workspace/data/hard_test_case/test/nail/fault...      1  0.361454
# 28  /workspace/data/hard_test_case/test/nail/fault...      1  0.191071
# 38  /workspace/data/hard_test_case/test/nail/fault...      1  0.152973
# 55  /workspace/data/hard_test_case/test/nail/good/...      0  0.875139
# 56  /workspace/data/hard_test_case/test/nail/good/...      0  0.817090
# 57  /workspace/data/hard_test_case/test/nail/good/...      0  0.868113
# 58  /workspace/data/hard_test_case/test/nail/good/...      0  0.534236
# 60  /workspace/data/hard_test_case/test/nail/good/...      0  0.712549
# 64  /workspace/data/hard_test_case/test/nail/good/...      0  0.555216
# 69  /workspace/data/hard_test_case/test/nail/good/...      0  0.651836
# 70  /workspace/data/hard_test_case/test/nail/good/...      0  0.767261
# 72  /workspace/data/hard_test_case/test/nail/good/...      0  0.781223
# 91  /workspace/data/hard_test_case/test/nail/good/...      0  0.473525
# 98  /workspace/data/hard_test_case/test/nail/good/...      0  0.801803
#
#     pr_sp_binary  failure
# 14             0     True
# 17             0     True
# 23             0     True
# 24             0     True
# 28             0     True
# 38             0     True
# 55             1     True
# 56             1     True
# 57             1     True
# 58             1     True
# 60             1     True
# 64             1     True
# 69             1     True
# 70             1     True
# 72             1     True
# 91             1     True
# 98             1     True

# %%
result_df_dict["visa"][result_df_dict["visa"]["failure"]]
# Out:
#                                             img_paths  gt_sp     pr_sp  \
# 23  /workspace/data/hard_test_case/test/nail/fault...      1  0.194131
# 28  /workspace/data/hard_test_case/test/nail/fault...      1  0.219168
# 38  /workspace/data/hard_test_case/test/nail/fault...      1  0.187131
# 42  /workspace/data/hard_test_case/test/nail/fault...      1  0.257310
# 55  /workspace/data/hard_test_case/test/nail/good/...      0  0.713414
# 56  /workspace/data/hard_test_case/test/nail/good/...      0  0.654730
# 57  /workspace/data/hard_test_case/test/nail/good/...      0  0.763688
# 58  /workspace/data/hard_test_case/test/nail/good/...      0  0.395134
# 60  /workspace/data/hard_test_case/test/nail/good/...      0  0.640720
# 64  /workspace/data/hard_test_case/test/nail/good/...      0  0.533246
# 69  /workspace/data/hard_test_case/test/nail/good/...      0  0.626127
# 70  /workspace/data/hard_test_case/test/nail/good/...      0  0.659799
# 72  /workspace/data/hard_test_case/test/nail/good/...      0  0.400256
# 91  /workspace/data/hard_test_case/test/nail/good/...      0  0.436420
# 98  /workspace/data/hard_test_case/test/nail/good/...      0  0.509075
#
#     pr_sp_binary  failure
# 23             0     True
# 28             0     True
# 38             0     True
# 42             0     True
# 55             1     True
# 56             1     True
# 57             1     True
# 58             1     True
# 60             1     True
# 64             1     True
# 69             1     True
# 70             1     True
# 72             1     True
# 91             1     True
# 98             1     True
